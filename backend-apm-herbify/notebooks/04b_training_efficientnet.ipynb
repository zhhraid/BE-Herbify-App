# %% [markdown]
# # 04b — Training Model EfficientNetB0
#
#
# Notebook ini bertugas untuk melatih arsitektur EfficientNetB0 dengan teknik transfer learning menggunakan dataset daun tanaman obat. Proses ini mengimpor fungsi-fungsi utama (Data Loader, Model, Config) secara langsung dari struktur backend App/.

# %% [markdown]
# ### [CELL 1] - Import Libraries
# <br><sub>**Maksud & Tujuan:** Memuat library bawaan Python, 	orch (PyTorch) untuk Deep Learning, serta memanggil fungsi bawaan kita dari pp/services/ dan konfigurasi dari pp/utils/config.py. Hal ini menjaga notebook tetap rapi dan terpusat.</sub>

# %%
import os
import sys
import json
import time
import copy
from pathlib import Path

import numpy as np
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
import torch.optim as optim
from torch.optim import lr_scheduler
from torchvision import models

# Tambahkan path backend ke sys.path agar bisa import dari app/
BASE_DIR = Path.cwd().parent  # backend/
sys.path.insert(0, str(BASE_DIR))

from app.services.preprocessing import get_data_loaders, get_class_names
from app.models.cnn_models import create_efficientnetb0
from app.utils.config import (
    MODEL_EFFICIENTNET_DIR, REPORTS_EVAL_DIR, MODEL_EFFICIENTNET_DIR,
    BATCH_SIZE, NUM_EPOCHS, LEARNING_RATE, DEVICE
)

print(f"🖥️  Device: {DEVICE}")
print(f"📂 Base directory: {BASE_DIR}")
# Out:
# 🖥️  Device: cpu
# 📂 Base directory: d:\SMT 6\ML\BE\backend-apm-herbify

# %% [markdown]
# ### [CELL 2] - Load Data
# <br><sub>**Maksud & Tujuan:** Memanggil get_data_loaders() dari services/preprocessing.py. Fungsi ini bertugas menarik gambar dari Folder Dataset untuk disuapkan ke model.<br>**Cara Kerjanya:** Gambar yang ditarik akan langsung di-**Augmentasi On-The-Fly** (diputar, dibalik, diberi efek pergeseran warna/cahaya secara instan di RAM tanpa menduplikat ukuran file di harddisk) dan dibaginya menjadi (80% Train, 20% Test) rata per *Batch*.
# <br>**Kenapa ukuran Batch Size nya 32?** Angka 32 (atau 16, 64) adalah standar ukuran kelipatan bit yang dioptimalkan secara arsitektur untuk *memory/VRAM GPU/RAM* komputer modern. Kalau kekecilan latihannya lama, kalau kebesaran (misal 512) memori RAM akan langsung jebol dan laptop macet (*Out of Memory*).</sub>

# %%
train_loader, test_loader = get_data_loaders(batch_size=BATCH_SIZE)
class_names = get_class_names()
num_classes = len(class_names)

print(f"\n📊 Dataset Info:")
print(f"   Jumlah kelas: {num_classes}")
print(f"   Train batches: {len(train_loader)}")
print(f"   Test batches: {len(test_loader)}")
# Out:
# ✅ Combined dataset sudah ada: 95 kelas
#
# 📊 Dataset Info:
#    Total gambar: 12031
#    Total kelas:  95
#    Train: 9624 gambar (80%)
#    Test:  2407 gambar (20%)
#    Train batches: 301
#    Test batches:  76
# ✅ Combined dataset sudah ada: 95 kelas
#
# 📊 Dataset Info:
#    Jumlah kelas: 95
#    Train batches: 301
#    Test batches: 76

# %% [markdown]
# ### [CELL 3] - Buat Model EfficientNetB0
# <br><sub>**Maksud & Tujuan:** Menginisialisasi otak buatan dari model.
# <br>**Bagaimana Algoritma EfficientNetB0 bekerja?**<br>Model ini dirancang khusus dari Google untuk arsitektur HP. Algoritma ini menggunakan trik *Depthwise Separable Convolutions*. Singkatnya: alih-alih membaca seluk beluk ruang (tepi, garis) dan warna (RGB) secara tebal di satu wadah besar, EfficientNetB0 malah memecahnya: ia baca polanya dulu, baru disablon warnanya. Teknik ini bisa memangkas parameter perhitungan matematika murni hingga **>70% lebih enteng**. Sehingga model hasilnya **berukuran file kecil (.pth nya kecil) dan pendeteksiannya super instan/cepat (hanya sekian milidetik)**, cocok banget dipasang ke HP Android/iOS!
# <br>**Kenapa ada Pretrained=True? (Transfer Learning)**<br>Kita meminjam memori 'otak' model dari lab Google yang aslinya sudah lulus sekolah menebak jutaan gambar dunia (ImageNet). Lalu, lapisan terakhir otaknya kita belah (potong) dan kita training ulang khusus untuk nama-nama tanaman kelas kita. Sangat menghemat waktu lho, dari hitungan bulan jadi hanya hitungan jam!</sub>

# %%
model = create_efficientnetb0(num_classes=num_classes, pretrained=True)
model = model.to(DEVICE)

# Hitung total parameter
total_params = sum(p.numel() for p in model.parameters())
trainable_params = sum(p.numel() for p in model.parameters() if p.requires_grad)

print(f"\n🧠 Model: EfficientNetB0")
print(f"   Total parameters: {total_params:,}")
print(f"   Trainable parameters: {trainable_params:,}")
print(f"   Frozen parameters: {total_params - trainable_params:,}")
# Out:
# 🧠 Model: EfficientNetB0
#    Total parameters: 4,129,243
#    Trainable parameters: 4,129,243
#    Frozen parameters: 0

# %% [markdown]
# ### [CELL 4] - Definisi Loss, Optimizer, Scheduler
# <br><sub>**Maksud & Tujuan:** Mengatur parameter 'Aturan Main' selama masa model belajar.
# <br>**Kenapa CrossEntropyLoss(weight=...)?** Ini adalah Rumus Hukuman. Kita sengaja menyuntikkan daftar *Class Weights* JSON kita ke sini. Jadi, kalau AI salah menebak daun mayoritas, model dipukul ringan. Tapi kalau salah nebak daun super langka yg gambarnya dikit, model dipukul puluhan kali secara penalti matematik! Otomatis kelakuan model jadi jauh lebih seimbang dan adil (tidak rasis ke daun yang banyak datanya).
# <br>**Kenapa Algoritma Optimizernya pakai Adam(lr=0.001)?** Adam itu algoritma mesin pencari titik nol kesalahan yang punya 'Momentum'. Ibarat bola menuruni bukit lembah salah, Adam bisa lari kencang. lr=0.001 (*Learning Rate*) adalah ukuran 'lebar langkah kaki'-nya. Kalau kebesaran model jalannya melompat lompat ngawur, kalau terlalu kecil jadinya super lambat. weight_decay=1e-4 adalah **rem blong (Regularisasi L2)** supaya model nggak sekadar 'menhafal mati' tapi beneran 'belajar pola'.
# <br>**Kenapa Scheduller StepLR(step_size=7, gamma=0.1)?** Fitur ini bertugas mengecilkan lambatnya *Learning Rate* (dikorting jadi 0.1/10%-nya) tiap berlalu **7 Epoch**. Ibarat main Golf: pas jarak target jauh pukulnya keras-keras, giliran hampir sampai sasaran akhir, pukulnya pelan-pelan supaya jatuhnya sempurna bola di lubang.
# <br>**Kenapa Epochs=25?** Satu Epoch itu = AI telah tuntas melihat SELURUH gambar dari 100+ spesies di Dataset sebanyak 1 putaran. 25 putaran (*Epoch*) adalah angka 'Golden Rule' rata-rata hemat untuk Transfer Learning. Di atas putaran segitu, model biasanya mentok alias *Overfitting* (pamer IPK gede padahal cuma jago hafalan, dipakai ke dunia nyata jawabnya salah total).</sub>

# %%
# ---------------------------------------------------------
# PENAMBAHAN CLASS WEIGHTS DARI HASIL PREPROCESSING
# ---------------------------------------------------------
import json
import torch

metadata_path = BASE_DIR / 'reports' / 'preprocessing' / 'preprocessing_metadata.json'
if metadata_path.exists():
    with open(metadata_path, 'r', encoding='utf-8') as f:
        metadata = json.load(f)
        print('✅ Membaca metadata Preprocessing... OTW inject Class Weights!')
        
    weights_dict = metadata.get('class_weights', {})
    
    weights_list = [weights_dict.get(c, 1.0) for c in class_names]
    weight_tensor = torch.tensor(weights_list, dtype=torch.float32).to(DEVICE)
    
    criterion = nn.CrossEntropyLoss(weight=weight_tensor)
    print(f'✅ Weighted CrossEntropyLoss diaktifkan untuk {len(class_names)} kelas.')
else:
    print('⚠️ preprocessing_metadata.json tidak ditemukan! Menjalankan mode normal (tanpa bobot).')
    criterion = nn.CrossEntropyLoss()
# ---------------------------------------------------------

optimizer = optim.Adam(model.parameters(), lr=LEARNING_RATE, weight_decay=1e-4)
scheduler = lr_scheduler.StepLR(optimizer, step_size=7, gamma=0.1)

print(f"\n⚙️  Training Config:")
print(f"   Loss function: CrossEntropyLoss (Weighted)")
print(f"   Optimizer: Adam (lr={LEARNING_RATE}, weight_decay=1e-4)")
print(f"   Scheduler: StepLR (step_size=7, gamma=0.1)")
print(f"   Epochs: {NUM_EPOCHS}")
print(f"   Batch size: {BATCH_SIZE}")
# Out:
# ✅ Membaca metadata Preprocessing... OTW inject Class Weights!
# ✅ Weighted CrossEntropyLoss diaktifkan untuk 95 kelas.
#
# ⚙️  Training Config:
#    Loss function: CrossEntropyLoss (Weighted)
#    Optimizer: Adam (lr=0.001, weight_decay=1e-4)
#    Scheduler: StepLR (step_size=7, gamma=0.1)
#    Epochs: 25
#    Batch size: 32

# %% [markdown]
# ### [CELL 5] - Training Loop
# <br><sub>**Maksud & Tujuan:** Menggiring model masuk ke kelas mesin belajar yang mutar-mutar sesuai jumlah epoch. Di tiap *epoch*nya punya dua fase ketat:
# 1. **Train Phase (model.train())**: Model nebak gambar, nilainya dicatat (loss), lalu kabel kabel sel otaknya langsung diperbaiki lewat koreksi balik/Backpropagation (loss.backward() & optimizer.step()).
# 2. **Val/Test Phase (model.eval())**: Model hanya diijinkan murni menjawab Ujian Akhir tanpa dituntun dosen. Kabel otaknya DILARANG DIREVISI, buat uji mental doang.
# <br>**Kenapa dipasang variabel est_model_wts?** Sering terjadi model itu ngeraih IPK terbaik misal pada *Epoch* ke-14, tapi abis itu saking jenuhnya dia grafiknya terjun bebas jadi goblok lagi di *Epoch* 25. Nah script ini pintar sekali, setiap melihat IPK tertinggi pecah rekor baru, memori jaringannya langsung auto-disekap (di-save di memori buffer). Akhirnya cuma masa jaya modelnya saja yang diselamatkan!</sub>

# %%
def train_model(model, criterion, optimizer, scheduler, train_loader, test_loader,
                num_epochs, device, model_name="efficientnetb0",
                patience=5, min_delta=0.0001):

    best_model_wts = copy.deepcopy(model.state_dict())
    best_acc = 0.0
    best_val_loss = float('inf')

    epochs_no_improve = 0

    history = {
        'train_loss': [], 'train_acc': [],
        'val_loss': [], 'val_acc': [],
        'epoch_time': [], 'lr': []
    }

    print(f"\n{'='*60}")
    print(f"Mulai Training: {model_name.upper()}")
    print(f"{'='*60}\n")

    for epoch in range(num_epochs):
        epoch_start = time.time()

        # ===== TRAIN =====
        model.train()
        running_loss = 0.0
        running_corrects = 0
        total_samples = 0

        for batch_idx, (inputs, labels) in enumerate(train_loader):
            inputs = inputs.to(device)
            labels = labels.to(device)

            optimizer.zero_grad()

            outputs = model(inputs)
            loss = criterion(outputs, labels)

            _, preds = torch.max(outputs, 1)

            loss.backward()
            optimizer.step()

            running_loss += loss.item() * inputs.size(0)
            running_corrects += (preds == labels).sum()
            total_samples += inputs.size(0)

            if batch_idx % 50 == 0:
                print(f"Epoch {epoch+1} | Batch {batch_idx}/{len(train_loader)}")

        train_loss = running_loss / total_samples
        train_acc = running_corrects.double() / total_samples

        # ===== VALIDASI =====
        model.eval()
        val_loss = 0.0
        val_corrects = 0
        val_total = 0

        with torch.no_grad():
            for inputs, labels in test_loader:
                inputs = inputs.to(device)
                labels = labels.to(device)

                outputs = model(inputs)
                loss = criterion(outputs, labels)

                _, preds = torch.max(outputs, 1)

                val_loss += loss.item() * inputs.size(0)
                val_corrects += (preds == labels).sum()
                val_total += inputs.size(0)

        val_loss /= val_total
        val_acc = val_corrects.double() / val_total

        scheduler.step()
        epoch_time = time.time() - epoch_start
        current_lr = optimizer.param_groups[0]['lr']

        history['train_loss'].append(train_loss)
        history['train_acc'].append(train_acc.item())
        history['val_loss'].append(val_loss)
        history['val_acc'].append(val_acc.item())
        history['epoch_time'].append(epoch_time)
        history['lr'].append(current_lr)

        print(f"\nEpoch [{epoch+1}/{num_epochs}] "
              f"Train Loss: {train_loss:.4f} Acc: {train_acc:.4f} | "
              f"Val Loss: {val_loss:.4f} Acc: {val_acc:.4f} | "
              f"Time: {epoch_time:.1f}s | LR: {current_lr:.6f}")

        # simpan model terbaik
        if val_acc > best_acc:
            best_acc = val_acc
            best_model_wts = copy.deepcopy(model.state_dict())
            print(f"   Model terbaik disimpan! (Val Acc: {best_acc:.4f})")

        # early stopping
        if val_loss < best_val_loss - min_delta:
            best_val_loss = val_loss
            epochs_no_improve = 0
        else:
            epochs_no_improve += 1
            print(f"   No improvement ({epochs_no_improve}/{patience})")

        if epochs_no_improve >= patience:
            print("\nEarly stopping aktif!")
            break

    print(f"\n{'='*60}")
    print(f"Training selesai!")
    print(f"Best Validation Accuracy: {best_acc:.4f}")
    print(f"Total training time: {sum(history['epoch_time']):.1f}s")
    print(f"{'='*60}")

    model.load_state_dict(best_model_wts)

    return model, history

model, history = train_model(
    model=model,
    criterion=criterion,
    optimizer=optimizer,
    scheduler=scheduler,
    train_loader=train_loader,
    test_loader=test_loader,
    num_epochs=25,      # fleksibel, nanti bisa berhenti sendiri
    device=DEVICE,
    model_name="efficientnetb0",
    patience=5,         # early stopping
    min_delta=0.0001
)
# Out:
# ============================================================
# Mulai Training: EFFICIENTNETB0
# ============================================================
#
# Epoch 1 | Batch 0/301
# Epoch 1 | Batch 50/301
# Epoch 1 | Batch 100/301
# Epoch 1 | Batch 150/301
# Epoch 1 | Batch 200/301
# Epoch 1 | Batch 250/301
# Epoch 1 | Batch 300/301
#
# Epoch [1/25] Train Loss: 1.9284 Acc: 0.5147 | Val Loss: 0.8249 Acc: 0.7690 | Time: 1302.2s | LR: 0.001000
#    Model terbaik disimpan! (Val Acc: 0.7690)
# Epoch 2 | Batch 0/301
# Epoch 2 | Batch 50/301
# Epoch 2 | Batch 100/301
# Epoch 2 | Batch 150/301
# Epoch 2 | Batch 200/301
# Epoch 2 | Batch 250/301
# Epoch 2 | Batch 300/301
#
# Epoch [2/25] Train Loss: 0.6702 Acc: 0.7944 | Val Loss: 0.4390 Acc: 0.8675 | Time: 1285.4s | LR: 0.001000
#    Model terbaik disimpan! (Val Acc: 0.8675)
# Epoch 3 | Batch 0/301
# Epoch 3 | Batch 50/301
# Epoch 3 | Batch 100/301
# Epoch 3 | Batch 150/301
# Epoch 3 | Batch 200/301
# Epoch 3 | Batch 250/301
# Epoch 3 | Batch 300/301
#
# Epoch [3/25] Train Loss: 0.4235 Acc: 0.8628 | Val Loss: 0.3956 Acc: 0.8795 | Time: 1593.0s | LR: 0.001000
#    Model terbaik disimpan! (Val Acc: 0.8795)
# Epoch 4 | Batch 0/301
# Epoch 4 | Batch 50/301
# Epoch 4 | Batch 100/301
# Epoch 4 | Batch 150/301
# Epoch 4 | Batch 200/301
# Epoch 4 | Batch 250/301
# Epoch 4 | Batch 300/301
#
# Epoch [4/25] Train Loss: 0.3351 Acc: 0.8920 | Val Loss: 0.2704 Acc: 0.9190 | Time: 1400.6s | LR: 0.001000
#    Model terbaik disimpan! (Val Acc: 0.9190)
# Epoch 5 | Batch 0/301
# Epoch 5 | Batch 50/301
# Epoch 5 | Batch 100/301
# Epoch 5 | Batch 150/301
# Epoch 5 | Batch 200/301
# Epoch 5 | Batch 250/301
# Epoch 5 | Batch 300/301
#
# Epoch [5/25] Train Loss: 0.2666 Acc: 0.9105 | Val Loss: 0.2354 Acc: 0.9290 | Time: 1069.5s | LR: 0.001000
#    Model terbaik disimpan! (Val Acc: 0.9290)
# Epoch 6 | Batch 0/301
# Epoch 6 | Batch 50/301
# Epoch 6 | Batch 100/301
# Epoch 6 | Batch 150/301
# Epoch 6 | Batch 200/301
# Epoch 6 | Batch 250/301
# Epoch 6 | Batch 300/301
#
# Epoch [6/25] Train Loss: 0.2576 Acc: 0.9142 | Val Loss: 0.3052 Acc: 0.9049 | Time: 1049.4s | LR: 0.001000
#    No improvement (1/5)
# Epoch 7 | Batch 0/301
# Epoch 7 | Batch 50/301
# Epoch 7 | Batch 100/301
# Epoch 7 | Batch 150/301
# Epoch 7 | Batch 200/301
# Epoch 7 | Batch 250/301
# Epoch 7 | Batch 300/301
#
# Epoch [7/25] Train Loss: 0.2302 Acc: 0.9226 | Val Loss: 0.3021 Acc: 0.9215 | Time: 827.2s | LR: 0.000100
#    No improvement (2/5)
# Epoch 8 | Batch 0/301
# Epoch 8 | Batch 50/301
# Epoch 8 | Batch 100/301
# Epoch 8 | Batch 150/301
# Epoch 8 | Batch 200/301
# Epoch 8 | Batch 250/301
# Epoch 8 | Batch 300/301
#
# Epoch [8/25] Train Loss: 0.1181 Acc: 0.9626 | Val Loss: 0.0798 Acc: 0.9738 | Time: 830.6s | LR: 0.000100
#    Model terbaik disimpan! (Val Acc: 0.9738)
# Epoch 9 | Batch 0/301
# Epoch 9 | Batch 50/301
# Epoch 9 | Batch 100/301
# Epoch 9 | Batch 150/301
# Epoch 9 | Batch 200/301
# Epoch 9 | Batch 250/301
# Epoch 9 | Batch 300/301
#
# Epoch [9/25] Train Loss: 0.0495 Acc: 0.9833 | Val Loss: 0.0672 Acc: 0.9792 | Time: 824.9s | LR: 0.000100
#    Model terbaik disimpan! (Val Acc: 0.9792)
# Epoch 10 | Batch 0/301
# Epoch 10 | Batch 50/301
# Epoch 10 | Batch 100/301
# Epoch 10 | Batch 150/301
# Epoch 10 | Batch 200/301
# Epoch 10 | Batch 250/301
# Epoch 10 | Batch 300/301
#
# Epoch [10/25] Train Loss: 0.0394 Acc: 0.9878 | Val Loss: 0.0560 Acc: 0.9821 | Time: 812.6s | LR: 0.000100
#    Model terbaik disimpan! (Val Acc: 0.9821)
# Epoch 11 | Batch 0/301
# Epoch 11 | Batch 50/301
# Epoch 11 | Batch 100/301
# Epoch 11 | Batch 150/301
# Epoch 11 | Batch 200/301
# Epoch 11 | Batch 250/301
# Epoch 11 | Batch 300/301
#
# Epoch [11/25] Train Loss: 0.0347 Acc: 0.9879 | Val Loss: 0.0562 Acc: 0.9859 | Time: 809.7s | LR: 0.000100
#    Model terbaik disimpan! (Val Acc: 0.9859)
#    No improvement (1/5)
# Epoch 12 | Batch 0/301
# Epoch 12 | Batch 50/301
# Epoch 12 | Batch 100/301
# Epoch 12 | Batch 150/301
# Epoch 12 | Batch 200/301
# Epoch 12 | Batch 250/301
# Epoch 12 | Batch 300/301
#
# Epoch [12/25] Train Loss: 0.0264 Acc: 0.9922 | Val Loss: 0.0491 Acc: 0.9855 | Time: 817.7s | LR: 0.000100
# Epoch 13 | Batch 0/301
# Epoch 13 | Batch 50/301
# Epoch 13 | Batch 100/301
# Epoch 13 | Batch 150/301
# Epoch 13 | Batch 200/301
# Epoch 13 | Batch 250/301
# Epoch 13 | Batch 300/301
#
# Epoch [13/25] Train Loss: 0.0282 Acc: 0.9897 | Val Loss: 0.0509 Acc: 0.9863 | Time: 816.7s | LR: 0.000100
#    Model terbaik disimpan! (Val Acc: 0.9863)
#    No improvement (1/5)
# Epoch 14 | Batch 0/301
# Epoch 14 | Batch 50/301
# Epoch 14 | Batch 100/301
# Epoch 14 | Batch 150/301
# Epoch 14 | Batch 200/301
# Epoch 14 | Batch 250/301
# Epoch 14 | Batch 300/301
#
# Epoch [14/25] Train Loss: 0.0272 Acc: 0.9920 | Val Loss: 0.0502 Acc: 0.9863 | Time: 822.3s | LR: 0.000010
#    No improvement (2/5)
# Epoch 15 | Batch 0/301
# Epoch 15 | Batch 50/301
# Epoch 15 | Batch 100/301
# Epoch 15 | Batch 150/301
# Epoch 15 | Batch 200/301
# Epoch 15 | Batch 250/301
# Epoch 15 | Batch 300/301
#
# Epoch [15/25] Train Loss: 0.0206 Acc: 0.9935 | Val Loss: 0.0483 Acc: 0.9859 | Time: 804.2s | LR: 0.000010
# Epoch 16 | Batch 0/301
# Epoch 16 | Batch 50/301
# Epoch 16 | Batch 100/301
# Epoch 16 | Batch 150/301
# Epoch 16 | Batch 200/301
# Epoch 16 | Batch 250/301
# Epoch 16 | Batch 300/301
#
# Epoch [16/25] Train Loss: 0.0199 Acc: 0.9925 | Val Loss: 0.0501 Acc: 0.9859 | Time: 814.9s | LR: 0.000010
#    No improvement (1/5)
# Epoch 17 | Batch 0/301
# Epoch 17 | Batch 50/301
# Epoch 17 | Batch 100/301
# Epoch 17 | Batch 150/301
# Epoch 17 | Batch 200/301
# Epoch 17 | Batch 250/301
# Epoch 17 | Batch 300/301
#
# Epoch [17/25] Train Loss: 0.0200 Acc: 0.9937 | Val Loss: 0.0490 Acc: 0.9871 | Time: 809.9s | LR: 0.000010
#    Model terbaik disimpan! (Val Acc: 0.9871)
#    No improvement (2/5)
# Epoch 18 | Batch 0/301
# Epoch 18 | Batch 50/301
# Epoch 18 | Batch 100/301
# Epoch 18 | Batch 150/301
# Epoch 18 | Batch 200/301
# Epoch 18 | Batch 250/301
# Epoch 18 | Batch 300/301
#
# Epoch [18/25] Train Loss: 0.0176 Acc: 0.9945 | Val Loss: 0.0489 Acc: 0.9875 | Time: 809.9s | LR: 0.000010
#    Model terbaik disimpan! (Val Acc: 0.9875)
#    No improvement (3/5)
# Epoch 19 | Batch 0/301
# Epoch 19 | Batch 50/301
# Epoch 19 | Batch 100/301
# Epoch 19 | Batch 150/301
# Epoch 19 | Batch 200/301
# Epoch 19 | Batch 250/301
# Epoch 19 | Batch 300/301
#
# Epoch [19/25] Train Loss: 0.0182 Acc: 0.9947 | Val Loss: 0.0461 Acc: 0.9884 | Time: 810.6s | LR: 0.000010
#    Model terbaik disimpan! (Val Acc: 0.9884)
# Epoch 20 | Batch 0/301
# Epoch 20 | Batch 50/301
# Epoch 20 | Batch 100/301
# Epoch 20 | Batch 150/301
# Epoch 20 | Batch 200/301
# Epoch 20 | Batch 250/301
# Epoch 20 | Batch 300/301
#
# Epoch [20/25] Train Loss: 0.0174 Acc: 0.9944 | Val Loss: 0.0489 Acc: 0.9859 | Time: 800.4s | LR: 0.000010
#    No improvement (1/5)
# Epoch 21 | Batch 0/301
# Epoch 21 | Batch 50/301
# Epoch 21 | Batch 100/301
# Epoch 21 | Batch 150/301
# Epoch 21 | Batch 200/301
# Epoch 21 | Batch 250/301
# Epoch 21 | Batch 300/301
#
# Epoch [21/25] Train Loss: 0.0198 Acc: 0.9936 | Val Loss: 0.0449 Acc: 0.9880 | Time: 802.1s | LR: 0.000001
# Epoch 22 | Batch 0/301
# Epoch 22 | Batch 50/301
# Epoch 22 | Batch 100/301
# Epoch 22 | Batch 150/301
# Epoch 22 | Batch 200/301
# Epoch 22 | Batch 250/301
# Epoch 22 | Batch 300/301
#
# Epoch [22/25] Train Loss: 0.0187 Acc: 0.9938 | Val Loss: 0.0448 Acc: 0.9884 | Time: 810.4s | LR: 0.000001
#    No improvement (1/5)
# Epoch 23 | Batch 0/301
# Epoch 23 | Batch 50/301
# Epoch 23 | Batch 100/301
# Epoch 23 | Batch 150/301
# Epoch 23 | Batch 200/301
# Epoch 23 | Batch 250/301
# Epoch 23 | Batch 300/301
#
# Epoch [23/25] Train Loss: 0.0164 Acc: 0.9948 | Val Loss: 0.0467 Acc: 0.9863 | Time: 808.9s | LR: 0.000001
#    No improvement (2/5)
# Epoch 24 | Batch 0/301
# Epoch 24 | Batch 50/301
# Epoch 24 | Batch 100/301
# Epoch 24 | Batch 150/301
# Epoch 24 | Batch 200/301
# Epoch 24 | Batch 250/301
# Epoch 24 | Batch 300/301
#
# Epoch [24/25] Train Loss: 0.0166 Acc: 0.9949 | Val Loss: 0.0444 Acc: 0.9871 | Time: 942.1s | LR: 0.000001
# Epoch 25 | Batch 0/301
# Epoch 25 | Batch 50/301
# Epoch 25 | Batch 100/301
# Epoch 25 | Batch 150/301
# Epoch 25 | Batch 200/301
# Epoch 25 | Batch 250/301
# Epoch 25 | Batch 300/301
#
# Epoch [25/25] Train Loss: 0.0163 Acc: 0.9955 | Val Loss: 0.0451 Acc: 0.9884 | Time: 1383.8s | LR: 0.000001
#    No improvement (1/5)
#
# ============================================================
# Training selesai!
# Best Validation Accuracy: 0.9884
# Total training time: 23859.1s
# ============================================================

# %% [markdown]
# ### [CELL 6] - Simpan Model & History
# <br><sub>**Maksud & Tujuan:** Menyimpan fisik parameter model terbaik hasil kurungan buffer dari sel 5 ke wujud nyata alias file ber-ekstensi .pth. Model format .pth inilah yang bisa di-eksport lalu ditaruh dicodingan API FastAPI nanti ke FrontEnd! File history.json-nya simpan statistik Epoch guna menggambar plot kurvanya.</sub>

# %%
# Simpan bobot model
model_path = os.path.join(MODEL_EFFICIENTNET_DIR, "efficientnetb0_best.pth")
torch.save(model.state_dict(), model_path)
print(f"💾 Model disimpan ke: {model_path}")
print(f"   Ukuran file: {os.path.getsize(model_path) / (1024*1024):.1f} MB")

# Simpan history training
history_path = os.path.join(MODEL_EFFICIENTNET_DIR, "efficientnetb0_history.json")
with open(history_path, 'w') as f:
    json.dump(history, f, indent=2)
print(f"📄 History disimpan ke: {history_path}")
# Out:
# 💾 Model disimpan ke: D:\SMT 6\ML\BE\backend-apm-herbify\trained_models\efficientnetb0\efficientnetb0_best.pth
#    Ukuran file: 16.0 MB
# 📄 History disimpan ke: D:\SMT 6\ML\BE\backend-apm-herbify\trained_models\efficientnetb0\efficientnetb0_history.json

# %% [markdown]
# ### [CELL 7] - Visualisasi Training History
# <br><sub>**Maksud & Tujuan:** Menilai kualitas grafis sihir dari jaring saraf. Grafik yang sehat (*Best Curve*) itu bila garis Train Accuracy dan Validation Accuracy **naik harmonis** beriringan, sedngkan angka Loss-nya **menukik landai asik** beriringan ke angka paling nol bareng. Kalau satu melayang naik satu nyungsep menjauh, wahai saudara.. itu namanya *Overfitting* yang jelek sekali.</sub>

# %%
fig, axes = plt.subplots(1, 2, figsize=(14, 5))

# Loss
axes[0].plot(history['train_loss'], label='Train Loss', color='#e74c3c', linewidth=2)
axes[0].plot(history['val_loss'], label='Val Loss', color='#3498db', linewidth=2)
axes[0].set_title('EfficientNetB0 — Loss per Epoch', fontsize=14, fontweight='bold')
axes[0].set_xlabel('Epoch')
axes[0].set_ylabel('Loss')
axes[0].legend()
axes[0].grid(True, alpha=0.3)

# Accuracy
axes[1].plot(history['train_acc'], label='Train Accuracy', color='#e74c3c', linewidth=2)
axes[1].plot(history['val_acc'], label='Val Accuracy', color='#3498db', linewidth=2)
axes[1].set_title('EfficientNetB0 — Accuracy per Epoch', fontsize=14, fontweight='bold')
axes[1].set_xlabel('Epoch')
axes[1].set_ylabel('Accuracy')
axes[1].legend()
axes[1].grid(True, alpha=0.3)

plt.tight_layout()
plt.savefig(os.path.join(REPORTS_EVAL_DIR, MODEL_EFFICIENTNET_DIR, 'training_history_efficientnetb0.png'), dpi=150, bbox_inches='tight')
plt.show()

# %% [markdown]
# ### [CELL 8] - Quick Evaluation on Test Set
# <br><sub>**Maksud & Tujuan:** Ini kayak tryout kilat instan kilat terakhir setelah kelulusan model. Kita cuma pengin liat **Total % Acc** nya berapa sama butuh waktu hitungan ms (*Miliseconds*) per tebakannya seberapa tokcer. Untuk grafik-grafikan super lengkapnya bakal dibantai habis di buku **05_model_comparison**.</sub>

# %%
model.eval()
test_corrects = 0
test_total = 0
inference_times = []

with torch.no_grad():
    for inputs, labels in test_loader:
        inputs, labels = inputs.to(DEVICE), labels.to(DEVICE)
        
        start_time = time.time()
        outputs = model(inputs)
        inference_times.append(time.time() - start_time)
        
        _, preds = torch.max(outputs, 1)
        test_corrects += torch.sum(preds == labels.data)
        test_total += inputs.size(0)

test_acc = test_corrects.double() / test_total
avg_inference = np.mean(inference_times) * 1000  # ms

print(f"\n📊 Quick Test Evaluation — EfficientNetB0")
print(f"   Test Accuracy: {test_acc:.4f} ({test_acc*100:.2f}%)")
print(f"   Avg Inference Time: {avg_inference:.2f} ms/batch")
print(f"   Model Size: {os.path.getsize(model_path) / (1024*1024):.1f} MB")
print(f"\n   → Evaluasi detail dilakukan di 05_model_comparison.ipynb")
# Out:
# 📊 Quick Test Evaluation — EfficientNetB0
#    Test Accuracy: 0.9884 (98.84%)
#    Avg Inference Time: 303.55 ms/batch
#    Model Size: 16.0 MB
#
#    → Evaluasi detail dilakukan di 05_model_comparison.ipynb
